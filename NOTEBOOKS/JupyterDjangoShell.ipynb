# %% [markdown]
# # ADA - KDA Py / ML Training
# ___
# #### My Experiments in Using Jup Notebooks INTERFACE for DJANGO dev and PY Machine Learning Courses
#
# (ML work dove-tails with prior SSAS - SQL SVr - work.)
# Motivated by prior work and intests in:
# + Machine Learning
# + R
# + Python
# + Web (incl/ Frameworks and Library)
# + MarkDown
# ---
# ** Resources: **
# + [Course](https://app.pluralsight.com/player?course=python-understanding-machine-learning&author=jerry-kurata&name=python-understanding-machine-learning-m1&clip=6&mode=live)
# + [Pandas Example](https://realpython.com/blog/python/working-with-large-excel-files-in-pandas/)
# + [BEAUTIFULSOUP](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# + [Jupyter Django Shell](https://www.calazan.com/using-ipython-notebook-django-shell-inside-docker-container/)
# + [MarkDown](http://assemble.io/docs/Cheatsheet-Markdown.html)
# + [SQLAlchemy](https://docs.sqlalchemy.org/en/rel_1_1/intro.html)
# + [Django](https://developer.mozilla.org/en-US/docs/Learn/Server-side/Django/Introduction)
# + [Pandas](http://pandas.pydata.org/)
# + [Django Pandas](https://github.com/chrisdev/django-pandas)
#
# + [jinja2](http://jinja.pocoo.org/docs/2.9/)

# %%
import html5lib
f = open("files/zipUtil.html")
tree = html5lib.parse(f)

# %%
tree
# Out:
# <Element '{http://www.w3.org/1999/xhtml}html' at 0x00000000018E0A48>

# %%
import pandas as pd
pd.test()
# Out:
# Running unit tests for pandas
# pandas version 0.19.2
# numpy version 1.12.0
# pandas is installed in C:\tools\python\lib\site-packages\pandas
# Python version 3.4.3 (v3.4.3:9b73f1c3e601, Feb 24 2015, 22:44:40) [MSC v.1600 64 bit (AMD64)]
# nose version 1.3.7
# C:\tools\python\lib\importlib\_bootstrap.py:321: FutureWarning: The pandas.rpy module is deprecated and will be removed in a future version. We refer to external packages like rpy2.
# See here for a guide on how to port your code to rpy2: http://pandas.pydata.org/pandas-docs/stable/r_interface.html
#   return f(*args, **kwds)
# .........S..SS..SS..SS..SS..SS..SS..SS..SSSSSSSSSSSSSS..SS..SS..SS....................SSSSSSSSSSSSSSSSSSSSSS...........SS..SS..SS..SS..SS..SS..SS................SSSSSSSSSSSSSSSS..SS..SS...................................S........................................................................................................................................S......................................................................................................S.................................................................................................................S.............S........................................................................................S...............................................S.................................................................S.............S.........................................................................S...............................................................................................................S.............S...........................................................S..........S.....E..........EE.......................SS..S........SS...SS..S.....................................................S.SSSS..................................................................................S....................................S.........................S.....................S............................S...................................................................................................................................................................................................................................................................................................................................S...........................S........................................................SSSSSSSSSSSSSSSSSSSSSSSSS..SS.....SSSSSSSSSSSSSSSSSSSSSSSSSSS..........................................................................................................................................................................................................................................................................................S.....................................................................................................................S.......................................S.........................................................................................................................S..S.......................................................................................................................................................................................................S..............................................................S...S......................................................................................................................................................................................................................................................................................................................................................................................................................S...........................................................................................................................................................................................................................................................................................................................S............................................................S...................................................................................S..........................................................................S. ...
#   return bool(asarray(a1 == a2).all())
# ...........................................................S.............................................................................................................................FF.FFFF.FF.FFFF....................................................................................S...........................................S......................S...........S...............S....S...............................S.......................................................................................................................................................................................................................................................................................................................S........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................S.................................................................................................S.S....S.........SS....................................................................................................................S.....SS.......................................................................S............................................................................SS...............................................................................................................................SS.........S..........S.........................S..........................................S........................................................................................................................................................................................................................................................................................................................................SSSSSSSSSS............S...S.....S...........................................S..........................S.
# ======================================================================
# ERROR: test_converters (pandas.io.tests.test_html.TestReadHtml)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\io\tests\test_html.py", line 715, in test_converters
#     html_df = read_html(html_data, converters={'a': str})[0]
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 896, in read_html
#     keep_default_na=keep_default_na)
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 723, in _parse
#     parser = _parser_dispatch(flav)
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 683, in _parser_dispatch
#     raise ImportError("lxml not found, please install it")
# ImportError: lxml not found, please install it
#
# ======================================================================
# ERROR: test_keep_default_na (pandas.io.tests.test_html.TestReadHtml)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\io\tests\test_html.py", line 756, in test_keep_default_na
#     html_df = read_html(html_data, keep_default_na=False)[0]
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 896, in read_html
#     keep_default_na=keep_default_na)
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 723, in _parse
#     parser = _parser_dispatch(flav)
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 683, in _parser_dispatch
#     raise ImportError("lxml not found, please install it")
# ImportError: lxml not found, please install it
#
# ======================================================================
# ERROR: test_na_values (pandas.io.tests.test_html.TestReadHtml)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\io\tests\test_html.py", line 736, in test_na_values
#     html_df = read_html(html_data, na_values=[0.244])[0]
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 896, in read_html
#     keep_default_na=keep_default_na)
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 723, in _parse
#     parser = _parser_dispatch(flav)
#   File "C:\tools\python\lib\site-packages\pandas\io\html.py", line 683, in _parser_dispatch
#     raise ImportError("lxml not found, please install it")
# ImportError: lxml not found, please install it
#
# ======================================================================
# FAIL: test_repr_max_columns_max_rows (pandas.tests.formats.test_format.TestDataFrameFormatting)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\formats\test_format.py", line 326, in test_repr_max_columns_max_rows
#     self.assertFalse(has_expanded_repr(df))
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_categorical_repr_datetime (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2252, in test_categorical_repr_datetime
#     self.assertEqual(repr(c), exp)
# AssertionError: '[201[193 chars]0:00, 2011-01-01 12:00:00, 2011-01-01 13:00:00]' != '[201[193 chars]0:00,\n                                 2011-0[31 chars]:00]'
# Diff is 661 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test_categorical_repr_datetime_ordered (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2306, in test_categorical_repr_datetime_ordered
#     self.assertEqual(repr(c), exp)
# AssertionError: '[201[196 chars]:00 < 2011-01-01 12:00:00 < 2011-01-01 13:00:00]' != '[201[196 chars]:00 <\n                                 2011-0[32 chars]:00]'
# Diff is 676 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test_categorical_repr_period (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2340, in test_categorical_repr_period
#     self.assertEqual(repr(c), exp)
# AssertionError: '[201[172 chars]11-01-01 12:00, 2011-01-01 13:00]' != '[201[172 chars]11-01-01 12:00,\n                            2011-01-01 13:00]'
#   [2011-01-01 09:00, 2011-01-01 10:00, 2011-01-01 11:00, 2011-01-01 12:00, 2011-01-01 13:00]
# - Categories (5, period[H]): [2011-01-01 09:00, 2011-01-01 10:00, 2011-01-01 11:00, 2011-01-01 12:00, 2011-01-01 13:00]?                                                                                                    ^^^^^^^^^^^^^^^^^^
# + Categories (5, period[H]): [2011-01-01 09:00, 2011-01-01 10:00, 2011-01-01 11:00, 2011-01-01 12:00,
# ?                                                                                                    ^
# +                             2011-01-01 13:00]
#
# ======================================================================
# FAIL: test_categorical_repr_period_ordered (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2369, in test_categorical_repr_period_ordered
#     self.assertEqual(repr(c), exp)
# AssertionError: '[201[176 chars]1-01-01 12:00 < 2011-01-01 13:00]' != '[201[176 chars]1-01-01 12:00 <\n                            2011-01-01 13:00]'
#   [2011-01-01 09:00, 2011-01-01 10:00, 2011-01-01 11:00, 2011-01-01 12:00, 2011-01-01 13:00]
# - Categories (5, period[H]): [2011-01-01 09:00 < 2011-01-01 10:00 < 2011-01-01 11:00 < 2011-01-01 12:00 < 2011-01-01 13:00]?                                                                                                        ^^^^^^^^^^^^^^^^^^
# + Categories (5, period[H]): [2011-01-01 09:00 < 2011-01-01 10:00 < 2011-01-01 11:00 < 2011-01-01 12:00 <
# ?                                                                                                        ^
# +                             2011-01-01 13:00]
#
# ======================================================================
# FAIL: test_categorical_repr_timedelta (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2413, in test_categorical_repr_timedelta
#     self.assertEqual(repr(c), exp)
# AssertionError: '[0 d[270 chars]0:00, 3 days 01:00:00, ..., 16 days 01:00:00, [49 chars]:00]' != '[0 d[270 chars]0:00,\n                                   3 da[121 chars]:00]'
#   [0 days 01:00:00, 1 days 01:00:00, 2 days 01:00:00, 3 days 01:00:00, 4 days 01:00:00, ..., 15 days 01:00:00, 16 days 01:00:00, 17 days 01:00:00, 18 days 01:00:00, 19 days 01:00:00]
#   Length: 20
# - Categories (20, timedelta64[ns]): [0 days 01:00:00, 1 days 01:00:00, 2 days 01:00:00, 3 days 01:00:00, ..., 16 days 01:00:00, 17 days 01:00:00, 18 days 01:00:00, 19 days 01:00:00]+ Categories (20, timedelta64[ns]): [0 days 01:00:00, 1 days 01:00:00, 2 days 01:00:00,
# +                                    3 days 01:00:00, ..., 16 days 01:00:00, 17 days 01:00:00,
# +                                    18 days 01:00:00, 19 days 01:00:00]
#
# ======================================================================
# FAIL: test_categorical_repr_timedelta_ordered (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2446, in test_categorical_repr_timedelta_ordered
#     self.assertEqual(repr(c), exp)
# AssertionError: '[0 d[273 chars]:00 < 3 days 01:00:00 ... 16 days 01:00:00 < 1[50 chars]:00]' != '[0 d[273 chars]:00 <\n                                   3 da[122 chars]:00]'
# Diff is 641 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test_categorical_series_repr_datetime (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2521, in test_categorical_series_repr_datetime
#     self.assertEqual(repr(s), exp)
# AssertionError: '0   [228 chars]0:00, 2011-01-01 12:00:00, 2011-01-01 13:00:00]' != '0   [228 chars]0:00,\n                                 2011-0[31 chars]:00]'
# Diff is 701 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test_categorical_series_repr_datetime_ordered (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2550, in test_categorical_series_repr_datetime_ordered
#     self.assertEqual(repr(s), exp)
# AssertionError: '0   [231 chars]:00 < 2011-01-01 12:00:00 < 2011-01-01 13:00:00]' != '0   [231 chars]:00 <\n                                 2011-0[32 chars]:00]'
# Diff is 716 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test_categorical_series_repr_period (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2579, in test_categorical_series_repr_period
#     self.assertEqual(repr(s), exp)
# AssertionError: '0   [207 chars]11-01-01 12:00, 2011-01-01 13:00]' != '0   [207 chars]11-01-01 12:00,\n                            2011-01-01 13:00]'
#   0   2011-01-01 09:00
#   1   2011-01-01 10:00
#   2   2011-01-01 11:00
#   3   2011-01-01 12:00
#   4   2011-01-01 13:00
#   dtype: category
# - Categories (5, period[H]): [2011-01-01 09:00, 2011-01-01 10:00, 2011-01-01 11:00, 2011-01-01 12:00, 2011-01-01 13:00]?                                                                                                    ^^^^^^^^^^^^^^^^^^
# + Categories (5, period[H]): [2011-01-01 09:00, 2011-01-01 10:00, 2011-01-01 11:00, 2011-01-01 12:00,
# ?                                                                                                    ^
# +                             2011-01-01 13:00]
#
# ======================================================================
# FAIL: test_categorical_series_repr_period_ordered (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2605, in test_categorical_series_repr_period_ordered
#     self.assertEqual(repr(s), exp)
# AssertionError: '0   [211 chars]1-01-01 12:00 < 2011-01-01 13:00]' != '0   [211 chars]1-01-01 12:00 <\n                            2011-01-01 13:00]'
# Diff is 641 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test_categorical_series_repr_timedelta (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2649, in test_categorical_series_repr_timedelta
#     self.assertEqual(repr(s), exp)
# AssertionError: '0   [303 chars]0:00, 3 days 01:00:00, ..., 6 days 01:00:00, 7[45 chars]:00]' != '0   [303 chars]0:00,\n                                   3 da[117 chars]:00]'
# Diff is 667 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test_categorical_series_repr_timedelta_ordered (pandas.tests.test_categorical.TestCategoricalAsBlock)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\tools\python\lib\site-packages\pandas\tests\test_categorical.py", line 2681, in test_categorical_series_repr_timedelta_ordered
#     self.assertEqual(repr(s), exp)
# AssertionError: '0   [306 chars]:00 < 3 days 01:00:00 ... 6 days 01:00:00 < 7 [46 chars]:00]' != '0   [306 chars]:00 <\n                                   3 da[118 chars]:00]'
# Diff is 675 characters long. Set self.maxDiff to None to see it.
#
# ----------------------------------------------------------------------
# Ran 10280 tests in 327.243s
#
# FAILED (SKIP=652, errors=3, failures=13)
# <nose.result.TextTestResult run=10280 errors=3 failures=13>

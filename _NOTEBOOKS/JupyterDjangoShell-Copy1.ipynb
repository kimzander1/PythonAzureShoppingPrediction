# %%
import html5lib
import pandas as pd
import lxml as html
from io import StringIO
from bs4 import BeautifulSoup

#------ test w/static file ------# 
f = open("_FILES/WXDATA.HTML")
tree = html5lib.parse(f)
soup = BeautifulSoup(open("_files/WXDATA.HTML"), "html5lib")
dfStatic = pd.DataFrame(columns=range(0,12), index = [0])

#-- drop the 1st row with NaNs.. So row[0] is the column names rows
dfStatic.drop(dfStatic.index[0], inplace=True)

#--- build dataframee
trCountStatic = len(srcTable.find_all('tr'))
for row in srcTable.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    for column in columns:
        dfStatic.iat[row_marker,column_marker] = column.get_text()
        column_marker += 1
trCountStatic
# Out:
# 20

# %%
#------ test w/dynamic source ------# 
url = 'https://www.glerl.noaa.gov//metdata/mkg/'
src = pd.read_html( url, header=1,flavor='html5lib')[3]
len(src)
src.
page
# Out:
#                                                    0    1     2   \
# 0   ----------------- Previous 18 Hours (at top of...  NaN   NaN
# 1                                                YEAR  DOY   EST
# 2                                                2017  050  2000
# 3                                                2017  050  1900
# 4                                                2017  050  1800
# 5                                                2017  050  1700
# 6                                                2017  050  1600
# 7                                                2017  050  1500
# 8                                                2017  050  1400
# 9                                                2017  050  1300
# 10                                               2017  050  1200
# 11                                               2017  050  1100
# 12                                               2017  050  1000
# 13                                               2017  050  0900
# 14                                               2017  050  0800
# 15                                               2017  050  0700
# 16                                               2017  050  0600
# 17                                               2017  050  0500
# 18                                               2017  050  0400
# 19                                               2017  050  0300
#
#               3            4            5           6             7   \
# 0            NaN          NaN          NaN         NaN           NaN
# 1   WindSpeedkts  WindGustkts  PeakWindkts  WindDirdeg  AirTempdeg F
# 2            3.3          3.5          3.5         166          36.7
# 3            6.8          7.0          7.4         209          35.6
# 4            3.5          4.3          7.6         199          37.9
# 5            2.5          2.9          5.6         242          40.3
# 6            4.5          4.9          4.9         328          38.7
# 7            8.6          8.7          9.1         339          39.4
# 8            8.9          9.7          9.7         342          40.1
# 9           10.1         10.3         10.9         342          39.2
# 10           9.7         10.3         11.9         338          39.4
# 11           9.3         10.1         11.1         329          38.3
# 12           4.3          4.7         10.1         323          37.2
# 13           2.9          3.5          7.6         323          35.8
# 14           3.9          4.9          4.9         322          34.9
# 15           2.9          4.5          5.4         335          35.4
# 16           5.2          5.4          6.6         320          34.0
# 17           6.4          6.6          7.0         317          34.9
# 18           5.8          6.0          7.0         308          35.4
# 19           3.9          4.1          6.0         301          35.8
#
#                8        9           10               11
# 0             NaN      NaN         NaN              NaN
# 1   DewPointdeg F  RelHum%  StaPressin  PARuEinst/m^2/s
# 2            33.9     89.6       29.48                2
# 3            33.6     92.3       29.48                2
# 4            33.6     84.2       29.46              129
# 5            34.1     78.4       29.45             1031
# 6            33.7     82.0       29.44             1526
# 7            34.2     81.5       29.43             1911
# 8            33.9     78.4       29.42             1963
# 9            33.8     80.9       29.41             1735
# 10           33.9     80.5       29.42             1926
# 11           33.5     82.6       29.41             1830
# 12           33.0     84.5       29.39              846
# 13           32.9     89.2       29.38             1307
# 14           32.0     89.2       29.35              310
# 15           32.2     88.0       29.32                2
# 16           31.7     91.4       29.29                2
# 17           32.3     90.0       29.27                2
# 18           32.8     90.2       29.25                2
# 19           33.3     90.4       29.23                2

# %% [raw]
# #soup.find("tbody")

# %% [raw]
# soup.select("#mainContentInner > table > tbody > tr:nth-of-type(3) > td > div > table > tbody > tr:nth-of-type(1) ")
# #print(type(t))
# #print(len(t))
# #print(t[0])

# %%
#t = soup.select("#mainContentInner > table > tbody > tr:nth-of-type(3) > td > div > table ")
#tstring = t[0]
#import pandas as pd
#from io import StringIO
#tstring
url = 'https://www.glerl.noaa.gov//metdata/mkg/'
tables = pd.read_html( url, flavor='html5lib')

print(type(tables))
print(len(tables))
print(tables[0])
#tables[21]
#pd.read_html( io=StringIO(tstring), flavor='html5lib')
#pd.( StringIO(tstring), html5lib)
# Out:
# <class 'list'>
# 4
#                                                   0    \
# 0   Back to Met Station Array Page Milwaukee | Chi...
# 1   Wind Speed: 2.5 kts (1.3 m/s)  Max Wind Speed:...
# 2                                         Wind Speed:
# 3                                     Max Wind Speed:
# 4                                     Wind Direction:
# 5                                    Air Temperature:
# 6                                          Dew Point:
# 7                                  Relative Humidity:
# 8                                   Station Pressure:
# 9                                 Sea Level Pressure:
# 10                                               PAR:
# 11  Data & Plots of Previous 3 Hours (2 minute inc...
# 12  Data & Plots of Previous 5 Days (hourly increm...
# 13  1 Day Windrose Plot, 5 Day Windrose Plot, (exp...
# 14  Click on image to enlarge(images updated 6X pe...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  6-hr animations  L to R: 1 2 3 4 5 6 7  Previo...
# 20  ----------------- Previous 18 Hours (at top of...
# 21  ----------------- Previous 18 Hours (at top of...
# 22                                               YEAR
# 23                                               2017
# 24                                               2017
# 25                                               2017
# 26                                               2017
# 27                                               2017
# 28                                               2017
# 29                                               2017
# 30                                               2017
# 31                                               2017
# 32                                               2017
# 33                                               2017
# 34                                               2017
# 35                                               2017
# 36                                               2017
# 37                                               2017
# 38                                               2017
# 39                                               2017
# 40                                               2017
# 41  Click here for today's 2-minute data: 20170219...
#
#                                                   1                  2    \
# 0                                                 NaN                NaN
# 1                                         Wind Speed:  2.5 kts (1.3 m/s)
# 2                                   2.5 kts (1.3 m/s)                NaN
# 3                                   2.9 kts (1.5 m/s)                NaN
# 4                                          242° (WSW)                NaN
# 5                                    40.3 °F (4.6 °C)                NaN
# 6                                    34.1 °F (1.2 °C)                NaN
# 7                                              78.4 %                NaN
# 8                            29.447 in Hg. (997.2 mb)                NaN
# 9                           30.110 in Hg. (1019.6 mb)                NaN
# 10                                 1031 uEinst/m2/sec                NaN
# 11                                                NaN                NaN
# 12                                                NaN                NaN
# 13                                                NaN                NaN
# 14                                                NaN                NaN
# 15                                                NaN                NaN
# 16                                                NaN                NaN
# 17                                                NaN                NaN
# 18                                                NaN                NaN
# 19                                                NaN                NaN
# 20  ----------------- Previous 18 Hours (at top of...               YEAR
# 21                                                NaN                NaN
# 22                                                DOY                EST
# 23                                                050               1700
# 24                                                050               1600
# 25                                                050               1500
# 26                                                050               1400
# 27                                                050               1300
# 28                                                050               1200
# 29                                                050               1100
# 30                                                050               1000
# 31                                                050               0900
# 32                                                050               0800
# 33                                                050               0700
# 34                                                050               0600
# 35                                                050               0500
# 36                                                050               0400
# 37                                                050               0300
# 38                                                050               0200
# 39                                                050               0100
# 40                                                050               0000
# 41                                                NaN                NaN
#
#                 3                  4                5            6    \
# 0               NaN                NaN              NaN          NaN
# 1   Max Wind Speed:  2.9 kts (1.5 m/s)  Wind Direction:   242° (WSW)
# 2               NaN                NaN              NaN          NaN
# 3               NaN                NaN              NaN          NaN
# 4               NaN                NaN              NaN          NaN
# 5               NaN                NaN              NaN          NaN
# 6               NaN                NaN              NaN          NaN
# 7               NaN                NaN              NaN          NaN
# 8               NaN                NaN              NaN          NaN
# 9               NaN                NaN              NaN          NaN
# 10              NaN                NaN              NaN          NaN
# 11              NaN                NaN              NaN          NaN
# 12              NaN                NaN              NaN          NaN
# 13              NaN                NaN              NaN          NaN
# 14              NaN                NaN              NaN          NaN
# 15              NaN                NaN              NaN          NaN
# 16              NaN                NaN              NaN          NaN
# 17              NaN                NaN              NaN          NaN
# 18              NaN                NaN              NaN          NaN
# 19              NaN                NaN              NaN          NaN
# 20              DOY                EST     WindSpeedkts  WindGustkts
# 21              NaN                NaN              NaN          NaN
# 22     WindSpeedkts        WindGustkts      PeakWindkts   WindDirdeg
# 23              2.5                2.9              2.9          242
# 24              4.5                4.9              4.9          328
# 25              8.6                8.7              9.1          339
# 26              8.9                9.7              9.7          342
# 27             10.1               10.3             10.9          342
# 28              9.7               10.3             11.9          338
# 29              9.3               10.1             11.1          329
# 30              4.3                4.7             10.1          323
# 31              2.9                3.5              7.6          323
# 32              3.9                4.9              4.9          322
# 33              2.9                4.5              5.4          335
# 34              5.2                5.4              6.6          320
# 35              6.4                6.6              7.0          317
# 36              5.8                6.0              7.0          308
# 37              3.9                4.1              6.0          301
# 38              3.7                4.7              4.7          215
# 39              7.4                7.8              8.4          225
# 40              8.4                8.7              9.1          199
# 41              NaN                NaN              NaN          NaN
#
#                  7                 8             9   ...   220  221  222  223  \
# 0                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 1   Air Temperature:  40.3 °F (4.6 °C)    Dew Point: ...   NaN  NaN  NaN  NaN
# 2                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 3                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 4                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 5                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 6                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 7                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 8                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 9                NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 10               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 11               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 12               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 13               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 14               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 15               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 16               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 17               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 18               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 19               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 20       PeakWindkts        WindDirdeg  AirTempdeg F ...   0.0  8.4  8.7  9.1
# 21               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
# 22      AirTempdeg F     DewPointdeg F       RelHum% ...   NaN  NaN  NaN  NaN
# 23              40.3              34.1          78.4 ...   NaN  NaN  NaN  NaN
# 24              38.7              33.7          82.0 ...   NaN  NaN  NaN  NaN
# 25              39.4              34.2          81.5 ...   NaN  NaN  NaN  NaN
# 26              40.1              33.9          78.4 ...   NaN  NaN  NaN  NaN
# 27              39.2              33.8          80.9 ...   NaN  NaN  NaN  NaN
# 28              39.4              33.9          80.5 ...   NaN  NaN  NaN  NaN
# 29              38.3              33.5          82.6 ...   NaN  NaN  NaN  NaN
# 30              37.2              33.0          84.5 ...   NaN  NaN  NaN  NaN
# 31              35.8              32.9          89.2 ...   NaN  NaN  NaN  NaN
# 32              34.9              32.0          89.2 ...   NaN  NaN  NaN  NaN
# 33              35.4              32.2          88.0 ...   NaN  NaN  NaN  NaN
# 34              34.0              31.7          91.4 ...   NaN  NaN  NaN  NaN
# 35              34.9              32.3          90.0 ...   NaN  NaN  NaN  NaN
# 36              35.4              32.8          90.2 ...   NaN  NaN  NaN  NaN
# 37              35.8              33.3          90.4 ...   NaN  NaN  NaN  NaN
# 38              37.4              34.8          90.1 ...   NaN  NaN  NaN  NaN
# 39              36.0              34.1          92.8 ...   NaN  NaN  NaN  NaN
# 40              37.9              35.1          89.3 ...   NaN  NaN  NaN  NaN
# 41               NaN               NaN           NaN ...   NaN  NaN  NaN  NaN
#
#       224   225   226   227    228  229
# 0     NaN   NaN   NaN   NaN    NaN  NaN
# 1     NaN   NaN   NaN   NaN    NaN  NaN
# 2     NaN   NaN   NaN   NaN    NaN  NaN
# 3     NaN   NaN   NaN   NaN    NaN  NaN
# 4     NaN   NaN   NaN   NaN    NaN  NaN
# 5     NaN   NaN   NaN   NaN    NaN  NaN
# 6     NaN   NaN   NaN   NaN    NaN  NaN
# 7     NaN   NaN   NaN   NaN    NaN  NaN
# 8     NaN   NaN   NaN   NaN    NaN  NaN
# 9     NaN   NaN   NaN   NaN    NaN  NaN
# 10    NaN   NaN   NaN   NaN    NaN  NaN
# 11    NaN   NaN   NaN   NaN    NaN  NaN
# 12    NaN   NaN   NaN   NaN    NaN  NaN
# 13    NaN   NaN   NaN   NaN    NaN  NaN
# 14    NaN   NaN   NaN   NaN    NaN  NaN
# 15    NaN   NaN   NaN   NaN    NaN  NaN
# 16    NaN   NaN   NaN   NaN    NaN  NaN
# 17    NaN   NaN   NaN   NaN    NaN  NaN
# 18    NaN   NaN   NaN   NaN    NaN  NaN
# 19    NaN   NaN   NaN   NaN    NaN  NaN
# 20  199.0  37.9  35.1  89.3  29.19  2.0
# 21    NaN   NaN   NaN   NaN    NaN  NaN
# 22    NaN   NaN   NaN   NaN    NaN  NaN
# 23    NaN   NaN   NaN   NaN    NaN  NaN
# 24    NaN   NaN   NaN   NaN    NaN  NaN
# 25    NaN   NaN   NaN   NaN    NaN  NaN
# 26    NaN   NaN   NaN   NaN    NaN  NaN
# 27    NaN   NaN   NaN   NaN    NaN  NaN
# 28    NaN   NaN   NaN   NaN    NaN  NaN
# 29    NaN   NaN   NaN   NaN    NaN  NaN
# 30    NaN   NaN   NaN   NaN    NaN  NaN
# 31    NaN   NaN   NaN   NaN    NaN  NaN
# 32    NaN   NaN   NaN   NaN    NaN  NaN
# 33    NaN   NaN   NaN   NaN    NaN  NaN
# 34    NaN   NaN   NaN   NaN    NaN  NaN
# 35    NaN   NaN   NaN   NaN    NaN  NaN
# 36    NaN   NaN   NaN   NaN    NaN  NaN
# 37    NaN   NaN   NaN   NaN    NaN  NaN
# 38    NaN   NaN   NaN   NaN    NaN  NaN
# 39    NaN   NaN   NaN   NaN    NaN  NaN
# 40    NaN   NaN   NaN   NaN    NaN  NaN
# 41    NaN   NaN   NaN   NaN    NaN  NaN
#
# [42 rows x 230 columns]

# %% [markdown]
# #### All Anchors
# #soup.find_all('a')

# %% [markdown]
# # ADA - KDA Py / ML Training
# ___
# #### My Experiments in Using Jup Notebooks INTERFACE for DJANGO dev and PY Machine Learning Courses
#
# (ML work dove-tails with prior SSAS - SQL SVr - work.)
# Motivated by prior work and intests in:
# + Machine Learning
# + R
# + Python
# + Web (incl/ Frameworks and Library)
# + MarkDown
# ---
# ** Resources: **
# + [Course](https://app.pluralsight.com/player?course=python-understanding-machine-learning&author=jerry-kurata&name=python-understanding-machine-learning-m1&clip=6&mode=live)
# + [Pandas 10min Example](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# + [Pandas Example](https://realpython.com/blog/python/working-with-large-excel-files-in-pandas/)
# + [BEAUTIFULSOUP](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# + [Jupyter Django Shell](https://www.calazan.com/using-ipython-notebook-django-shell-inside-docker-container/)
# + [MarkDown](http://assemble.io/docs/Cheatsheet-Markdown.html)
# + [SQLAlchemy](https://docs.sqlalchemy.org/en/rel_1_1/intro.html)
# + [Django](https://developer.mozilla.org/en-US/docs/Learn/Server-side/Django/Introduction)
# + [Pandas](http://pandas.pydata.org/)
# + [Django Pandas](https://github.com/chrisdev/django-pandas)
#
# + [jinja2](http://jinja.pocoo.org/docs/2.9/)

# %% [markdown]
# #mainContentInner > table > tbody > tr:nth-child(3)
# //*[@id="mainContentInner"]/table/tbody/tr[3]
# #mainContentInner > table > tbody > tr:nth-child(3) > td > div > table > tbody > tr:nth-child(1)
# //*[@id="mainContentInner"]/table/tbody/tr[3]/td/div/table/tbody/tr[1]
